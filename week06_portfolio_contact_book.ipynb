# %%
# TODO: Create a dictionary called `contacts` with 3 entries
# Each key is a name, each value is a phone number (string)

contacts = {
    "Alice": "0400 123 456",
    "Bob": "0411 222 333",
    "Charlie": "0422 555 777",
}
contacts

# TODO: Add yourself (or another name) to the contacts dictionary

contacts["Vanessa"] = "0499 888 111"
contacts

# TODO: Change Bob's number

contacts["Bob"] = "0408 000 999"
contacts

# TODO: Loop and print each contact

for name, phone in contacts.items():
    print(f"{name}: {phone}")

    # TODO: Convert contacts to nested structure

contacts = {
    "Alice":   {"phone": "0400 123 456", "email": "alice@example.com"},
    "Bob":     {"phone": "0408 000 999", "email": "bob@example.com"},
    "Charlie": {"phone": "0422 555 777", "email": "charlie@example.com"},
    "Vanessa": {"phone": "0499 888 111", "email": "vanessa@example.com"},
}
contacts

# TODO: Loop and print both phone and email

for name, details in contacts.items():
    print(f"{name}")
    print(f"  Phone: {details['phone']}")
    print(f"  Email: {details['email']}\n")

    critique_notes = """
1) The data for each person is inside a list called 'v' with no clear key names.
   You must remember that v[1] is phone and v[3] is email — very confusing.

2) The structure mixes lists and dictionaries in a way that makes lookups slow
   and unclear. You must loop through 'people' to find someone by name.

Redesign idea:
Use a simple dictionary of dictionaries:
{
    "Alice": {"phone": "...", "email": "..."},
    "Bob":   {"phone": "...", "email": "..."}
}
Much easier for lookups and updates.
"""
# Out:
# Alice: 0400 123 456
# Bob: 0408 000 999
# Charlie: 0422 555 777
# Vanessa: 0499 888 111
# Alice
#   Phone: 0400 123 456
#   Email: alice@example.com
#
# Bob
#   Phone: 0408 000 999
#   Email: bob@example.com
#
# Charlie
#   Phone: 0422 555 777
#   Email: charlie@example.com
#
# Vanessa
#   Phone: 0499 888 111
#   Email: vanessa@example.com
