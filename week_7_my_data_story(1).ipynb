# %% [markdown]
# Read the file and create a code

# %%
# Define the filename you want to read. Make sure this file exists in your Colab environment.
file_name = '/content/SHOPPING LIST.txt'

try:
    # Open the file in read mode ('r').
    # The 'with' statement ensures the file is automatically closed after its block, even if errors occur.
    with open(file_name, 'r') as file:
        # Read all the content from the file.
        file_content = file.read()

        # Print the content of the file.
        print("Content of the file:")
        print(file_content)
except FileNotFoundError:
    # If the file doesn't exist at the specified path, print an error message.
    print(f"Error: The file '{file_name}' was not found. Please make sure it exists.")
except Exception as e:
    # Catch any other potential errors during file processing.
    print(f"An error occurred: {e}")
# Out:
# Content of the file:
# Fruits and Vegetables.
# Dairy and eggs.
# Meat and Sea food.
# Pantry items.
# Snack and Drinks.
# Household items.
# Personal care.

# %%
Add another line with a different item

# %%
# Define the filename
file_name = '/content/SHOPPING LIST.txt'

try:
    # Open the file in append mode ('a'). This will add content to the end of the file.
    with open(file_name, 'a') as file:
        file.write('\nFrozen food.')
    print(f"'Frozen food.' has been added to '{file_name}'.")
except Exception as e:
    print(f"An error occurred while adding to the file: {e}")
# Out:
# 'Frozen food.' has been added to '/content/SHOPPING LIST.txt'.

# %% [markdown]
# Read and display the added item.

# %%
# Now, let's read and display the updated content of the file to confirm.
file_name = '/content/SHOPPING LIST.txt'

try:
    with open(file_name, 'r') as file:
        updated_content = file.read()
        print("\nUpdated content of the file:")
        print(updated_content)
except FileNotFoundError:
    print(f"Error: The file '{file_name}' was not found.")
except Exception as e:
    print(f"An error occurred while reading the file: {e}")
# Out:
# Updated content of the file:
# Fruits and Vegetables.
# Dairy and eggs.
# Meat and Sea food.
# Pantry items.
# Snack and Drinks.
# Household items.
# Personal care.
#
# Frozen food.

# %% [markdown]
# Count the number of lines in the code.

# %%
# Define the filename
file_name = '/content/SHOPPING LIST.txt'

try:
    # Open the file in read mode ('r').
    with open(file_name, 'r') as file:
        # Read all lines from the file into a list
        lines = file.readlines()
        # Count the number of lines
        line_count = len(lines)

        print(f"The file '{file_name}' contains {line_count} lines.")
except FileNotFoundError:
    print(f"Error: The file '{file_name}' was not found. Please make sure it exists.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# The file '/content/SHOPPING LIST.txt' contains 9 lines.

# %% [markdown]
# Define the longest, first and last line.Add a suitable tittle.

# %%
# Define the filename
file_name = '/content/SHOPPING LIST.txt'

try:
    with open(file_name, 'r') as file:
        lines = file.readlines()

        # Remove newline characters and strip whitespace from each line
        cleaned_lines = [line.strip() for line in lines if line.strip()]

        if not cleaned_lines:
            print(f"The file '{file_name}' is empty or contains only whitespace.")
        else:
            # Add a nice header
            print("\n--- Shopping List Analysis ---\n")

            # Find the longest line
            longest_line = max(cleaned_lines, key=len)

            # Get the first line
            first_line = cleaned_lines[0]

            # Get the last line
            last_line = cleaned_lines[-1]

            print(f"Longest line: '{longest_line}' (Length: {len(longest_line)})\n")
            print(f"First line: '{first_line}'")
            print(f"Last line: '{last_line}'")

except FileNotFoundError:
    print(f"Error: The file '{file_name}' was not found. Please make sure it exists.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# --- Shopping List Analysis ---
#
# Longest line: 'Fruits and Vegetables.' (Length: 22)
#
# First line: 'Fruits and Vegetables.'
# Last line: 'Frozen food.'

# %% [markdown]
# Working with files surprised me because I didn’t realise how simple it is to organise and analyse basic text content.
#
#
# AI helped by giving me clear steps and showing me how to summarise the file professionally.
#
#
# It also made the process quicker by providing templates I could use.
#
#
# Next, I’d like to learn how to work with more advanced files like spreadsheets or databases.

# %% [markdown]
# AI Collaboration – Step-by-Step Explanation (Text Form)
# Step 1: Starting the Task
#
# I began by asking the AI how to read a file in Python. I wanted to display the contents and understand how file handling works in Google Colab.
#
# Step 2: AI Provides Basic File-Reading Code
#
# The AI gave me the first block of code that opens a file using with open(...) and reads the text inside. It also explained why try–except is useful for catching errors like missing files.
#
# Step 3: Adding New Items to the File
#
# I asked how to add another line to my shopping list.
# The AI showed me how to use append mode ('a') and explained that this adds text to the end of the file without deleting existing content.
#
# Step 4: Displaying Updated Content
#
# After adding a new item, the AI helped me write code to reopen the file and display all lines again so I could confirm the update worked.
#
# Step 5: Counting the Number of Lines
#
# I wanted to know how many items were in the file.
# The AI guided me to use readlines() and len() to count the number of lines.
#
# Step 6: Finding the First, Last, and Longest Lines
#
# The AI also helped me analyse the file content by cleaning the lines and then using:
#
# cleaned_lines[0] → first line
#
# cleaned_lines[-1] → last line
#
# max(cleaned_lines, key=len) → longest line
#
# It also suggested adding a title like “SHOPPING LIST ANALYSIS” to make the output look professional.
#
# Step 7: Formatting the File Information Section
#
# When I needed the final version for my assignment, the AI helped me:
#
# print the filename
#
# count total characters
#
# show the contents with numbered lines
#
# It guided me to structure everything cleanly in a single code block.
#
# Step 8: Writing the AI Collaboration Section
#
# Finally, the AI helped me write a reflective explanation of:
#
# one prompt I used
#
# what the AI explained
#
# what I learned from working with the AI
#
# This step made the assignment look complete and academically acceptable.
